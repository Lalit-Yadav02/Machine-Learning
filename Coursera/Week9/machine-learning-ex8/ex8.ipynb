# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import loadmat
from scipy.optimize import minimize
# %matplotlib inline

# %%
data = loadmat('data/ex8data1.mat')
X = data['X']

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 2, 1.2])
axes.plot(X[:, 0], X[:, 1], 'bx', markersize = 3.5)
axes.set_xlabel('Latency (ms)')
axes.set_ylabel('Throught (mb/s)')
axes.set_title('Anamoly')
# Out:
# Text(0.5, 1.0, 'Anamoly')

# %%
def estimate_gaussian(X):
    return X.mean(axis=0), np.cov(X.T)

# %%
mu, sigma = estimate_gaussian(X)

# %%
def multivariate(X, mu, sigma):
    k = len(X)
    if sigma.ndim == 1:
        sigma = np.diag(sigma)
    X = X - mu
    return (2 * np.pi) ** (-k/2) * np.linal
# Out:
# array([14.11222578, 14.99771051])

# %%
np.pi
# Out:
# 3.141592653589793

# %%
return (2 * np.pi)**(-k/2) * np.linalg.det(sigma2)**(-0.5) * \
        np.exp( -0.5 * np.sum( np.multiply( X.dot( np.linalg.inv(sigma2) ), X ), axis=1 ) ).reshape( ( X.shape[0], 1 ) )
